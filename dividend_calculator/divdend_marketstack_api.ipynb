# %%
import pandas as pd
from pathlib import Path
# %matplotlib inline
import numpy as np
import json 
import requests

# %%
market_stack_url = 'https://api.marketstack.com/v1/eod'
MS_API_Key = 'd4dae97b992f9679cb6e46d027601db2'



params = {
  'access_key': 'd4dae97b992f9679cb6e46d027601db2'
}

api_result = requests.get('https://api.marketstack.com/v1/tickers/aapl/eod', params)

api_result
# Out:
# <Response [200]>

# %%
api_response = api_result.json()
api_response
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 2517},
#  'data': {'name': 'Apple Inc',
#   'symbol': 'AAPL',
#   'country': None,
#   'has_intraday': False,
#   'has_eod': True,
#   'eod': [{'open': 163.85,
#     'high': 164.07,
#     'low': 154.95,
#     'close': 156.77,
#     'volume': 130139508.0,
#     'adj_high': None,
#     'adj_low': None,
#     'adj_close': 156.77,
#     'adj_open': None,
#     'adj_volume': None,
#     'split_factor': 1.0,
#     'dividend': 0.0,
#     'symbol': 'AAPL',
#     'exchange': 'XNAS',
#     'date': '2022-05-05T00:00:00+0000'},
#    {'open': 159.67,
#     'high': 166.47,
#     'low': 159.26,
#     'close': 166.02,
#     'volume': 108256503.0,
#     'adj_high': None,
#     'adj_low': None,
#     'adj_close': 166.02,
#     'adj_open': None,
#     'adj_volume': None,
#     'split_factor': 1.0,
#     'dividend': 0.0,
#     'symbol': 'AAPL',
#     'exchange': 'XNAS',
#     'date': '2022-05-04T00:00:00+0000'},
#    {'open': 158.15,
# ...

# %%
for stock_data in api_response['data']:
    print(u'Ticker %s has a day high of  %s on %s' % (
      stock_data['symbol']
      stock_data['high']
      stock_data['date']
    ))ate']
